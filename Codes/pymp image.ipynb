# %% [markdown]
# #Required

# %%
# !pip install pymp-pypi

# %%
import numpy as np
import time
import pandas as pd
import glob
import cv2
import pymp

from sklearn.model_selection import train_test_split

# %% [markdown]
# #Dataset

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

# %%
y = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/HPC Project/image labels.csv")
y = y.values

# %%
X = []

for img in glob.glob("/content/drive/MyDrive/Colab Notebooks/HPC Project/image KNN/*.jpg"):
    image = cv2.imread(img)
    image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    image = cv2.resize(image,(500,500),interpolation = cv2.INTER_AREA)
    image = image.flatten()
    X.append(image)
    
X = np.array(X)

# %% [markdown]
# #KNN

# %%
class KNN():

    def __init__(self):

        self.X_train = []
        self.y_train = []

    def euclidian(self,x1,x2):

        difference =  np.subtract(x1,x2)
        square_difference = np.power(difference,2)
        sum_square_difference = np.sum(square_difference)

        return sum_square_difference**(0.5)

    def fit(self,X,y):

        self.X_train = X
        self.y_train = y

    def predict(self,X_test,k,process):

        y_pred = pymp.shared.array(X_test.shape[0],dtype = np.int16)

        with pymp.Parallel(num_threads = process) as p:
            for i in p.range(X_test.shape[0]):

                distances = []

                for j in range(self.X_train.shape[0]):

                    distances.append(self.euclidian(X_train[j],X_test[i]))

                indeces = np.argsort(np.array(distances))
                
                sol = []

                for K in range(k):

                    sol.append(self.y_train[indeces[K]])

                y_pred[i] = np.bincount(sol).argmax()

            return y_pred

# %% [markdown]
# #Compute

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.1,stratify=y)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,2)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,4)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,6)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,stratify=y)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,2)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,4)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,6)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.5,stratify=y)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,2)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,4)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,6)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.7,stratify=y)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,2)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,4)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,6)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.9,stratify=y)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,2)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,4)

# %%
# %%time
model = KNN()
model.fit(X_train,y_train.reshape(y_train.shape[0],))
y_pred = model.predict(X_test,10,6)
